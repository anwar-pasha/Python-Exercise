# %%
list = ["Element1","Element1","Element3","Element4"]
print(list)
# Out:
# ['Element1', 'Element1', 'Element3', 'Element4']

# %%
ans = []
for i in list:
    if i not in ans:
        ans.append(i)
print(ans)
# Out:
# ['Element1', 'Element3', 'Element4']
